# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#x = np.arange(-1,1,0.1)
x = np.linspace(-1,1,16)
y = np.square(x**2)
plt.figure(figsize=(10,6))
plt.plot(x,y,color = 'red',linestyle='-')
plt.scatter(x,y,color = 'Green')
plt.bar(x,y,color = 'silver',width = 0.05)
#plt.xlim((-2,2))
#plt.ylim((-1,2))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv',delimiter=",",header = 0)

#x,y = data[["x","y"]]
X = data["x"]
Y = data["y"]

u = np.linspace(20,70,100)

plt.plot(u,1.4*u + 0.1,color='red')

plt.scatter(X,Y)
plt.show()

# %%
def Least_Square(k,b,x_data,y_data):
    
    X = np.linspace(20,70,100)
    plt.plot(X,k*X + b,color='red')
    plt.scatter(x_data,y_data)
    
    totalError = 0
#   print(len(x_data))
    for i in range(0,len(x_data)):
        
        totalError += ( (k*x_data[i] + b) -y_data[i])**2
    return totalError/float(len(x_data))/2.0


print("---Least_square--------------")
MeanError = Least_Square(0,0,X,Y)
print(MeanError)
print("-----------------")
# Out:
# ---Least_square--------------
# 100
# 2782.553917245276
# -----------------

# %%
def Gradient_Descent(k,b,x_data,y_data,epochs,lr):
    
    m = float(len(x_data))
    print(m)
    for i in range(0,epochs):
        k_grad = 0
        b_grad = 0
        for j in range(0,mount):
            k_grad += (1/m) * ((k*x_data[j] + b) - y_data[j]) * x_data[j]
            b_grad += (1/m) * ( k*x_data[j] + b - y_data[j] )

        k = k - lr*k_grad
        b = b - lr*b_grad
    return k,b


        
Least_Square(0,0,X,Y)
print("------------------------")
k,b = Gradient_Descent(0,0,X,Y,50,0.01)
Least_Square(k,b,X,Y)
# Out:
# -----------------
# 100
# ------------------------
# 100.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a0b0d8acf08d> in <module>()
#      34 Least_Square(0,0,X,Y)
#      35 print("------------------------")
# ---> 36 k,b = Gradient_Descent(0,0,X,Y,50,0.01)
#      37 Least_Square(k,b,X,Y)
#      38
#
# <ipython-input-7-a0b0d8acf08d> in Gradient_Descent(k, b, x_data, y_data, epochs, lr)
#      22         k_grad = 0
#      23         b_grad = 0
# ---> 24         for j in range(0,mount):
#      25             k_grad += (1/m) * ((k*x_data[j] + b) - y_data[j]) * x_data[j]
#      26             b_grad += (1/m) * ( k*x_data[j] + b - y_data[j] )
#
# NameError: name 'mount' is not defined
