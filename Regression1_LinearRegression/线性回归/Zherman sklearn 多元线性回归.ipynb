# %%
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt  
from mpl_toolkits.mplot3d import Axes3D

# %%
data = np.genfromtxt('Delivery.csv',delimiter = ',')

x = data[1:,:-1]

y = data[1:,-1]
# print(y)
# print(x)
print(data)
# Out:
# [[  nan   nan   nan]
#  [100.    4.    9.3]
#  [ 50.    3.    4.8]
#  [100.    4.    8.9]
#  [100.    2.    6.5]
#  [ 50.    2.    4.2]
#  [ 80.    2.    6.2]
#  [ 75.    3.    7.4]
#  [ 65.    4.    6. ]
#  [ 90.    3.    7.6]
#  [ 90.    2.    6.1]]

# %%
model = linear_model.LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(model.coef_)
print(model.intercept_)
print(model.predict([[102,4]]))
# Out:
# [0.0611346  0.92342537]
# -0.868701466781709
# [9.06072908]

# %%
'''
1.mpl_toolkits.mplot3d import Axes3D
'''
ax = plt.figure().add_subplot(111,projection = '3d')
ax.scatter(x[:,0],x[:,1],y,c='b',marker = 'o',s = 100)

#grid
X,Y = np.meshgrid(x[:,0],x[:,1])
z = model.coef_[0]*X + model.coef_[1]*Y + model.intercept_
#ax.plot(X,Y,z)
ax.plot_surface(X,Y,z)

# ax.set_xlabel('Miles')  
# ax.set_ylabel('Num of Deliveries')  
# ax.set_zlabel('Time') 
plt.show()
