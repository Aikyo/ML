# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#x = np.arange(-1,1,0.1)
x = np.linspace(-1,1,16)
y = np.square(x**2)
plt.figure(figsize=(10,6))
plt.plot(x,y,color = 'red',linestyle='-')
plt.scatter(x,y,color = 'Green')
plt.bar(x,y,color = 'silver',width = 0.05)
#plt.xlim((-2,2))
#plt.ylim((-1,2))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv',delimiter=",",header = 0)

#x,y = data[["x","y"]]
X = data["x"]
Y = data["y"]

u = np.linspace(20,70,100)

plt.plot(u,1.4*u + 0.1,color='red')

plt.scatter(X,Y)
plt.show()

# %%
x = 10
print('ff{0}'.format(x))
# Out:
# ff10

# %%
def Least_Square(k,b,x_data,y_data):
    
    X = np.linspace(20,70,100)
    plt.plot(X,k*X + b,color='red')
    plt.scatter(x_data,y_data)
    
    totalError = 0
    length = len(x_data)
    print('数据集大小 : {0}'.format(length)
    
    for i in range(0,len(x_data)):
        totalError += ( (k*x_data[i] + b) -y_data[i])**2
    return totalError/float(len(x_data))/2.0

meanError = Least_Square(1.5,0,X,Y)
print(meanError)
# Out:
#   File "<ipython-input-16-668c1faee83a>", line 11
#     for i in range(0,len(x_data)):
#                                  ^
# SyntaxError: invalid syntax

# %%
def Least_Square(k,b,x_data,y_data):
    
    X = np.linspace(20,70,100)
    plt.plot(X,k*X + b,color='red')
    plt.scatter(x_data,y_data)
    
    totalError = 0
    print(len(x_data))
    for i in range(0,len(x_data)):
        
        totalError += ( (k*x_data[i] + b) -y_data[i])**2
    return totalError/float(len(x_data))/2.0

Least_Squ
print("-----------------")

def Gradient_Descent(k,b,x_data,y_data,epochs,lr):
    
    mount = len(x_data)
    for i in range(0,epochs):
        k_grad = 0
        b_grad = 0
        for j in range(0,mount):
            k_grad += 1/len(x_data) * ((k*x_data[j] + b) - y_data[j]) * x_data[j]
            b_grad += 1/len(y_data) * ( k*x_data[j] + b - y_data[j] )

        k = k - lr*k_grad
        b = b - lr*b_grad
    return k,b


        
Least_Square(0,0,X,Y)
print("------------------------")
k,b = Gradient_Descent(0,0,X,Y,50,0.01)
Least_Square(k,b,X,Y)
# Out:
# 100
# ------------------------
# 100
# 2.0431014493509674e+141
