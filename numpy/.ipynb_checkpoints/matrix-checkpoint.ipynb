# %%
import numpy as np
''''''

# %%
'''
1.矩阵的求逆，和转置
'''

data = np.genfromtxt("data.csv",delimiter = ',')
print(data.shape)
mat = np.mat(data)
# print(data.shape)
# print(mat)
mat.T
mat.I
# Out:
# (100, 2)
# matrix([[ 2.28138707e-03,  1.56265776e-03,  3.98567229e-03,
#           1.89760455e-05,  4.05852449e-04,  6.63999774e-04,
#          -1.04912292e-04,  2.27538106e-05, -3.53190418e-04,
#           1.05745508e-03,  1.76235257e-03, -5.31202764e-05,
#           6.14747711e-04,  1.63421523e-03,  5.54852112e-04,
#           1.73371194e-03, -2.02382083e-03, -8.30851648e-04,
#           2.63150557e-03,  2.28298823e-04,  2.11049499e-03,
#          -2.60119025e-03,  1.89718794e-03,  1.49567033e-03,
#           3.81962620e-04,  1.95500602e-03, -1.17045546e-03,
#           1.09522546e-04, -1.11297997e-03, -9.30785530e-04,
#           2.03571498e-03,  1.61473154e-03, -1.64610459e-03,
#          -1.17362150e-03,  1.67440050e-03,  2.66548439e-04,
#           2.06144804e-03, -9.79422799e-05, -9.32847548e-04,
#          -5.14446661e-04,  1.91701627e-03,  8.98640280e-04,
#          -9.57599537e-04,  6.33276853e-04, -2.64125763e-03,
# ...
